# %%
#imports

import numpy as np
import Sparse_Subpixel_Convolution as SpConv

from PIL import Image
import matplotlib.pylab as plt
from matplotlib.patches import Rectangle

from ipywidgets import Layout, interact, IntSlider, FloatSlider
import time
import gc


#Consts
nanometers_per_pixel = 46

dt = 0.1
t_max = 6.4

psf_peak_pixel_size = 32

camera_fov_px = 64

steps = int(t_max / dt)

exD = 5000.0
exParticle_count = 100
# Out:
# Sparse_Subpixel_Convolution module initialized!

# %%
#Load PSF
PSF_subpx = np.load("../PSF_subpx_fl64.npy")
sample_size_px = PSF_subpx.shape[2] - camera_fov_px
print("Sample width: ", sample_size_px)
# Out:
# Sample width:  448

# %%
FOV_edge = sample_size_px / 2 - camera_fov_px / 2

sample_count = 100

PSF_subpx_fl64 = PSF_subpx.astype('float64')
PSF_subpx_fl32 = PSF_subpx.astype('float32')

PSF_subpx_ui32 = (PSF_subpx * 65535.0).astype('uint32')
PSF_subpx_ui16 = (PSF_subpx * 255.0).astype('uint16')
    
def GenParticlePositions(D : float, particle_count : int, step_count : int, loop : bool):
    variance = 4 * D * dt / (nanometers_per_pixel ** 2)

    start_poss = np.random.uniform(0, sample_size_px, (particle_count, 2))
    dposs = np.random.normal(0, variance, (step_count, particle_count, 2))

    poss = start_poss[None, :, :] + np.cumsum(dposs, axis = 0)
    
    s = sample_size_px
    
    if(loop):
        poss[poss < 0] = poss[poss < 0] + np.floor(-poss[poss < 0] / s + 1) * s
        poss[poss > s] = poss[poss > s] - np.floor( poss[poss > s] / s + 0) * s
    
    poss -= FOV_edge
    
    return poss #shape: (steps, particle_count, coordinates)

sz = camera_fov_px
subpixels = PSF_subpx.shape[0]



import multiprocessing
number_of_threads = multiprocessing.cpu_count()
print(number_of_threads)

threads_begin = 1
threads_end = number_of_threads
# Out:
# 64

# %%
#Benchmark

startTime = time.time()

particle_count = exParticle_count * sample_count

poss = GenParticlePositions(exD, particle_count, steps, True)
sample_sizes = np.full((sample_count), exParticle_count, dtype=np.int32)

print("Particle generation done in " + str(time.time() - startTime) + " s")


#Convolution

def test_convolution_parallel_omp(thread_count, particle_positions, step_count, particle_count, datatyp):    
    intensities = np.full((particle_count), 1, dtype=datatyp)

    startTime = time.time()
    
    psf = PSF_subpx    
    if datatyp == np.float64:
        psf = PSF_subpx_fl64
    if datatyp == np.float32:
        psf = PSF_subpx_fl32
    if datatyp == np.uint32:
        psf = PSF_subpx_ui32
    if datatyp == np.uint16:
        psf = PSF_subpx_ui16        

    samples = SpConv.convolve(thread_count, camera_fov_px, poss, sample_sizes, intensities, psf, datatyp, verbose=0)
    
    perf = time.time() - startTime
    return [samples, perf]


#Testing

datatypes = [np.float64, np.float32, np.uint32, np.uint16]
str_types = ["fl64", "fl32", "ui32", "ui16"]
perfs_omp = np.zeros((len(datatypes), threads_end - threads_begin))

sampless = list()

for d in range(len(datatypes)):
    print("Datatype: " + str_types[d])
    for i in range(threads_begin, threads_end):
        samples, perfs_omp[d, i-threads_begin] = test_convolution_parallel_omp(i, poss, steps, particle_count, datatypes[d])
        print("\t Threads: " + str(i) + "--- Convolutions done in " + str(perfs_omp[d, i-threads_begin]) + " s")
    sampless.append(samples)

    plt.plot(perfs_omp[d])
plt.legend(str_types)

plt.show()
# Out:
# Particle generation done in 0.05679059028625488 s
# Datatype: fl64
# 	 Threads: 1--- Convolutions done in 8.26891803741455 s
# 	 Threads: 2--- Convolutions done in 4.6323792934417725 s
# 	 Threads: 3--- Convolutions done in 3.744067430496216 s
# 	 Threads: 4--- Convolutions done in 3.1915218830108643 s
# 	 Threads: 5--- Convolutions done in 2.7730987071990967 s
# 	 Threads: 6--- Convolutions done in 2.5896804332733154 s
# 	 Threads: 7--- Convolutions done in 2.449770450592041 s
# 	 Threads: 8--- Convolutions done in 2.3701157569885254 s
# 	 Threads: 9--- Convolutions done in 2.290741205215454 s
# 	 Threads: 10--- Convolutions done in 2.215789794921875 s
# 	 Threads: 11--- Convolutions done in 2.2347240447998047 s
# 	 Threads: 12--- Convolutions done in 2.1488616466522217 s
# 	 Threads: 13--- Convolutions done in 2.122528314590454 s
# 	 Threads: 14--- Convolutions done in 2.0802831649780273 s
# 	 Threads: 15--- Convolutions done in 2.01625394821167 s
# 	 Threads: 16--- Convolutions done in 2.483783006668091 s
# 	 Threads: 17--- Convolutions done in 2.0920956134796143 s
# 	 Threads: 18--- Convolutions done in 2.0154688358306885 s
# 	 Threads: 19--- Convolutions done in 1.9954228401184082 s
# 	 Threads: 20--- Convolutions done in 2.429154396057129 s
# 	 Threads: 21--- Convolutions done in 1.9483568668365479 s
# 	 Threads: 22--- Convolutions done in 2.60395884513855 s
# 	 Threads: 23--- Convolutions done in 2.1154189109802246 s
# 	 Threads: 24--- Convolutions done in 2.1102280616760254 s
# 	 Threads: 25--- Convolutions done in 1.8958673477172852 s
# 	 Threads: 26--- Convolutions done in 2.289802312850952 s
# 	 Threads: 27--- Convolutions done in 1.900022268295288 s
# 	 Threads: 28--- Convolutions done in 2.3126962184906006 s
# 	 Threads: 29--- Convolutions done in 1.9352171421051025 s
# 	 Threads: 30--- Convolutions done in 2.3881726264953613 s
# 	 Threads: 31--- Convolutions done in 2.0757510662078857 s
# 	 Threads: 32--- Convolutions done in 2.0240838527679443 s
# 	 Threads: 33--- Convolutions done in 2.846261501312256 s
# 	 Threads: 34--- Convolutions done in 2.0343430042266846 s
# 	 Threads: 35--- Convolutions done in 2.1270315647125244 s
# 	 Threads: 36--- Convolutions done in 2.0419962406158447 s
# 	 Threads: 37--- Convolutions done in 2.016545534133911 s
# 	 Threads: 38--- Convolutions done in 3.1016173362731934 s
# 	 Threads: 39--- Convolutions done in 2.187730550765991 s
# 	 Threads: 40--- Convolutions done in 2.043375015258789 s
# 	 Threads: 41--- Convolutions done in 2.0447511672973633 s
# 	 Threads: 42--- Convolutions done in 1.880795955657959 s
# 	 Threads: 43--- Convolutions done in 2.2365405559539795 s
# 	 Threads: 44--- Convolutions done in 1.9487450122833252 s
# 	 Threads: 45--- Convolutions done in 2.3085813522338867 s
# 	 Threads: 46--- Convolutions done in 1.9552762508392334 s
# 	 Threads: 47--- Convolutions done in 2.3331079483032227 s
# 	 Threads: 48--- Convolutions done in 2.0405280590057373 s
# 	 Threads: 49--- Convolutions done in 2.589041233062744 s
# 	 Threads: 50--- Convolutions done in 1.9920258522033691 s
# 	 Threads: 51--- Convolutions done in 2.779385566711426 s
# 	 Threads: 52--- Convolutions done in 1.9900448322296143 s
# 	 Threads: 53--- Convolutions done in 2.9795243740081787 s
# 	 Threads: 54--- Convolutions done in 2.291058301925659 s
# 	 Threads: 55--- Convolutions done in 2.4496991634368896 s
# 	 Threads: 56--- Convolutions done in 1.886225700378418 s
# 	 Threads: 57--- Convolutions done in 2.2339839935302734 s
# 	 Threads: 58--- Convolutions done in 1.8723626136779785 s
# 	 Threads: 59--- Convolutions done in 2.2543163299560547 s
# 	 Threads: 60--- Convolutions done in 1.8734002113342285 s
# 	 Threads: 61--- Convolutions done in 2.3244969844818115 s
# 	 Threads: 62--- Convolutions done in 1.9914448261260986 s
# 	 Threads: 63--- Convolutions done in 1.9503161907196045 s
# Datatype: fl32
# 	 Threads: 1--- Convolutions done in 4.494495391845703 s
# 	 Threads: 2--- Convolutions done in 2.840437412261963 s
# 	 Threads: 3--- Convolutions done in 2.0211551189422607 s
# 	 Threads: 4--- Convolutions done in 2.333387613296509 s
# 	 Threads: 5--- Convolutions done in 1.6308071613311768 s
# 	 Threads: 6--- Convolutions done in 1.6393210887908936 s
# 	 Threads: 7--- Convolutions done in 1.3504526615142822 s
# 	 Threads: 8--- Convolutions done in 1.2771050930023193 s
# 	 Threads: 9--- Convolutions done in 1.2218575477600098 s
# 	 Threads: 10--- Convolutions done in 1.199699878692627 s
# 	 Threads: 11--- Convolutions done in 1.185258388519287 s
# 	 Threads: 12--- Convolutions done in 1.1661314964294434 s
# 	 Threads: 13--- Convolutions done in 1.1391956806182861 s
# 	 Threads: 14--- Convolutions done in 1.1128463745117188 s
# 	 Threads: 15--- Convolutions done in 1.1029586791992188 s
# 	 Threads: 16--- Convolutions done in 1.0929951667785645 s
# 	 Threads: 17--- Convolutions done in 1.0862703323364258 s
# 	 Threads: 18--- Convolutions done in 1.084336519241333 s
# 	 Threads: 19--- Convolutions done in 1.0915799140930176 s
# 	 Threads: 20--- Convolutions done in 1.0609774589538574 s
# 	 Threads: 21--- Convolutions done in 1.0782055854797363 s
# 	 Threads: 22--- Convolutions done in 1.0722601413726807 s
# 	 Threads: 23--- Convolutions done in 1.0663845539093018 s
# 	 Threads: 24--- Convolutions done in 1.061943531036377 s
# 	 Threads: 25--- Convolutions done in 1.0423002243041992 s
# 	 Threads: 26--- Convolutions done in 1.0494792461395264 s
# 	 Threads: 27--- Convolutions done in 1.0379045009613037 s
# 	 Threads: 28--- Convolutions done in 1.047938346862793 s
# 	 Threads: 29--- Convolutions done in 1.035902976989746 s
# 	 Threads: 30--- Convolutions done in 1.0570387840270996 s
# 	 Threads: 31--- Convolutions done in 1.045818567276001 s
# 	 Threads: 32--- Convolutions done in 1.0751864910125732 s
# 	 Threads: 33--- Convolutions done in 1.0321276187896729 s
# 	 Threads: 34--- Convolutions done in 1.0678107738494873 s
# 	 Threads: 35--- Convolutions done in 1.0337419509887695 s
# 	 Threads: 36--- Convolutions done in 1.0412957668304443 s
# 	 Threads: 37--- Convolutions done in 1.0405912399291992 s
# 	 Threads: 38--- Convolutions done in 1.0423696041107178 s
# 	 Threads: 39--- Convolutions done in 1.02305269241333 s
# 	 Threads: 40--- Convolutions done in 1.0648243427276611 s
# 	 Threads: 41--- Convolutions done in 1.051058053970337 s
# 	 Threads: 42--- Convolutions done in 1.062671422958374 s
# 	 Threads: 43--- Convolutions done in 1.0371737480163574 s
# 	 Threads: 44--- Convolutions done in 1.0237433910369873 s
# 	 Threads: 45--- Convolutions done in 1.021918535232544 s
# 	 Threads: 46--- Convolutions done in 1.0240519046783447 s
# 	 Threads: 47--- Convolutions done in 1.023721694946289 s
# 	 Threads: 48--- Convolutions done in 1.0192651748657227 s
# 	 Threads: 49--- Convolutions done in 1.3578522205352783 s
# 	 Threads: 50--- Convolutions done in 1.017841100692749 s
# 	 Threads: 51--- Convolutions done in 1.0720164775848389 s
# 	 Threads: 52--- Convolutions done in 1.028557538986206 s
# 	 Threads: 53--- Convolutions done in 1.0357537269592285 s
# 	 Threads: 54--- Convolutions done in 1.0217840671539307 s
# 	 Threads: 55--- Convolutions done in 1.0373282432556152 s
# 	 Threads: 56--- Convolutions done in 1.0268163681030273 s
# 	 Threads: 57--- Convolutions done in 1.0232341289520264 s
# 	 Threads: 58--- Convolutions done in 1.5514473915100098 s
# 	 Threads: 59--- Convolutions done in 1.056678056716919 s
# 	 Threads: 60--- Convolutions done in 1.2639460563659668 s
# 	 Threads: 61--- Convolutions done in 1.0317847728729248 s
# 	 Threads: 62--- Convolutions done in 1.0357928276062012 s
# 	 Threads: 63--- Convolutions done in 1.0374467372894287 s
# Datatype: ui32
# 	 Threads: 1--- Convolutions done in 6.5842812061309814 s
# 	 Threads: 2--- Convolutions done in 3.681187391281128 s
# 	 Threads: 3--- Convolutions done in 2.8239262104034424 s
# 	 Threads: 4--- Convolutions done in 2.278275966644287 s
# 	 Threads: 5--- Convolutions done in 2.035398483276367 s
# 	 Threads: 6--- Convolutions done in 1.8056762218475342 s
# 	 Threads: 7--- Convolutions done in 1.813863754272461 s
# 	 Threads: 8--- Convolutions done in 1.5532917976379395 s
# 	 Threads: 9--- Convolutions done in 1.6797738075256348 s
# 	 Threads: 10--- Convolutions done in 1.4087858200073242 s
# 	 Threads: 11--- Convolutions done in 1.568166732788086 s
# 	 Threads: 12--- Convolutions done in 1.3215177059173584 s
# 	 Threads: 13--- Convolutions done in 1.3278770446777344 s
# 	 Threads: 14--- Convolutions done in 1.2621209621429443 s
# 	 Threads: 15--- Convolutions done in 1.2218782901763916 s
# 	 Threads: 16--- Convolutions done in 1.2019734382629395 s
# 	 Threads: 17--- Convolutions done in 1.1623725891113281 s
# 	 Threads: 18--- Convolutions done in 1.1654160022735596 s
# 	 Threads: 19--- Convolutions done in 1.162909984588623 s
# 	 Threads: 20--- Convolutions done in 1.133777141571045 s
# 	 Threads: 21--- Convolutions done in 1.1202585697174072 s
# 	 Threads: 22--- Convolutions done in 1.1167757511138916 s
# 	 Threads: 23--- Convolutions done in 1.1420087814331055 s
# 	 Threads: 24--- Convolutions done in 1.1188948154449463 s
# 	 Threads: 25--- Convolutions done in 1.105039358139038 s
# 	 Threads: 26--- Convolutions done in 1.0811655521392822 s
# 	 Threads: 27--- Convolutions done in 1.079949140548706 s
# 	 Threads: 28--- Convolutions done in 1.0853779315948486 s
# 	 Threads: 29--- Convolutions done in 1.0749530792236328 s
# 	 Threads: 30--- Convolutions done in 1.0789844989776611 s
# 	 Threads: 31--- Convolutions done in 1.070011854171753 s
# 	 Threads: 32--- Convolutions done in 1.0781102180480957 s
# 	 Threads: 33--- Convolutions done in 1.056877851486206 s
# 	 Threads: 34--- Convolutions done in 1.0512919425964355 s
# 	 Threads: 35--- Convolutions done in 1.047001838684082 s
# 	 Threads: 36--- Convolutions done in 1.0874664783477783 s
# 	 Threads: 37--- Convolutions done in 1.0881590843200684 s
# 	 Threads: 38--- Convolutions done in 1.044342279434204 s
# 	 Threads: 39--- Convolutions done in 1.053210735321045 s
# 	 Threads: 40--- Convolutions done in 1.038872480392456 s
# 	 Threads: 41--- Convolutions done in 1.0539584159851074 s
# 	 Threads: 42--- Convolutions done in 1.034325361251831 s
# 	 Threads: 43--- Convolutions done in 1.0499987602233887 s
# 	 Threads: 44--- Convolutions done in 1.033491611480713 s
# 	 Threads: 45--- Convolutions done in 1.038022518157959 s
# 	 Threads: 46--- Convolutions done in 1.0363147258758545 s
# 	 Threads: 47--- Convolutions done in 1.043755054473877 s
# 	 Threads: 48--- Convolutions done in 1.0676383972167969 s
# 	 Threads: 49--- Convolutions done in 1.0725512504577637 s
# 	 Threads: 50--- Convolutions done in 1.027362585067749 s
# 	 Threads: 51--- Convolutions done in 1.0305862426757812 s
# 	 Threads: 52--- Convolutions done in 1.0123891830444336 s
# 	 Threads: 53--- Convolutions done in 1.0220930576324463 s
# 	 Threads: 54--- Convolutions done in 1.5081946849822998 s
# 	 Threads: 55--- Convolutions done in 1.010986566543579 s
# 	 Threads: 56--- Convolutions done in 1.0057613849639893 s
# 	 Threads: 57--- Convolutions done in 1.0161848068237305 s
# 	 Threads: 58--- Convolutions done in 1.0090770721435547 s
# 	 Threads: 59--- Convolutions done in 1.5554735660552979 s
# 	 Threads: 60--- Convolutions done in 1.0005292892456055 s
# 	 Threads: 61--- Convolutions done in 1.0135140419006348 s
# 	 Threads: 62--- Convolutions done in 1.4711644649505615 s
# 	 Threads: 63--- Convolutions done in 1.0141024589538574 s
# Datatype: ui16
# 	 Threads: 1--- Convolutions done in 2.433725357055664 s
# 	 Threads: 2--- Convolutions done in 1.29595947265625 s
# 	 Threads: 3--- Convolutions done in 1.0410993099212646 s
# 	 Threads: 4--- Convolutions done in 0.8730039596557617 s
# 	 Threads: 5--- Convolutions done in 0.7818772792816162 s
# 	 Threads: 6--- Convolutions done in 0.7111423015594482 s
# 	 Threads: 7--- Convolutions done in 0.6753196716308594 s
# 	 Threads: 8--- Convolutions done in 0.6327011585235596 s
# 	 Threads: 9--- Convolutions done in 0.6092383861541748 s
# 	 Threads: 10--- Convolutions done in 0.6614201068878174 s
# 	 Threads: 11--- Convolutions done in 0.5811004638671875 s
# 	 Threads: 12--- Convolutions done in 0.5576841831207275 s
# 	 Threads: 13--- Convolutions done in 0.5538873672485352 s
# 	 Threads: 14--- Convolutions done in 0.5354673862457275 s
# 	 Threads: 15--- Convolutions done in 0.533322811126709 s
# 	 Threads: 16--- Convolutions done in 0.517465353012085 s
# 	 Threads: 17--- Convolutions done in 0.5218613147735596 s
# 	 Threads: 18--- Convolutions done in 0.5137126445770264 s
# 	 Threads: 19--- Convolutions done in 0.5209815502166748 s
# 	 Threads: 20--- Convolutions done in 0.5259339809417725 s
# 	 Threads: 21--- Convolutions done in 0.5145001411437988 s
# 	 Threads: 22--- Convolutions done in 0.5117754936218262 s
# 	 Threads: 23--- Convolutions done in 0.5086703300476074 s
# 	 Threads: 24--- Convolutions done in 0.5012252330780029 s
# 	 Threads: 25--- Convolutions done in 0.5025255680084229 s
# 	 Threads: 26--- Convolutions done in 0.5151956081390381 s
# 	 Threads: 27--- Convolutions done in 0.5153367519378662 s
# 	 Threads: 28--- Convolutions done in 0.5010485649108887 s
# 	 Threads: 29--- Convolutions done in 0.4997518062591553 s
# 	 Threads: 30--- Convolutions done in 0.5013725757598877 s
# 	 Threads: 31--- Convolutions done in 0.6448276042938232 s
# 	 Threads: 32--- Convolutions done in 0.5014638900756836 s
# 	 Threads: 33--- Convolutions done in 0.4898200035095215 s
# 	 Threads: 34--- Convolutions done in 0.497312068939209 s
# 	 Threads: 35--- Convolutions done in 0.5089306831359863 s
# 	 Threads: 36--- Convolutions done in 0.8066720962524414 s
# 	 Threads: 37--- Convolutions done in 0.515251636505127 s
# 	 Threads: 38--- Convolutions done in 0.5035574436187744 s
# 	 Threads: 39--- Convolutions done in 0.5070114135742188 s
# 	 Threads: 40--- Convolutions done in 0.5035727024078369 s
# 	 Threads: 41--- Convolutions done in 0.7668893337249756 s
# 	 Threads: 42--- Convolutions done in 0.5250911712646484 s
# 	 Threads: 43--- Convolutions done in 0.5065937042236328 s
# 	 Threads: 44--- Convolutions done in 0.5065610408782959 s
# 	 Threads: 45--- Convolutions done in 0.5088901519775391 s
# 	 Threads: 46--- Convolutions done in 0.8125417232513428 s
# 	 Threads: 47--- Convolutions done in 0.4984130859375 s
# 	 Threads: 48--- Convolutions done in 0.4937772750854492 s
# 	 Threads: 49--- Convolutions done in 0.4953269958496094 s
# 	 Threads: 50--- Convolutions done in 0.4936387538909912 s
# 	 Threads: 51--- Convolutions done in 0.6899445056915283 s
# 	 Threads: 52--- Convolutions done in 0.5077958106994629 s
# 	 Threads: 53--- Convolutions done in 0.6547274589538574 s
# 	 Threads: 54--- Convolutions done in 0.5082242488861084 s
# 	 Threads: 55--- Convolutions done in 0.5771627426147461 s
# 	 Threads: 56--- Convolutions done in 0.5027031898498535 s
# 	 Threads: 57--- Convolutions done in 0.5023984909057617 s
# 	 Threads: 58--- Convolutions done in 0.4978020191192627 s
# 	 Threads: 59--- Convolutions done in 0.5058176517486572 s
# 	 Threads: 60--- Convolutions done in 0.4954812526702881 s
# 	 Threads: 61--- Convolutions done in 0.4914841651916504 s
# 	 Threads: 62--- Convolutions done in 0.5025532245635986 s
# 	 Threads: 63--- Convolutions done in 0.4871823787689209 s

# %%
#Draw Fast
sample_inds = np.insert(np.cumsum(sample_sizes), 0, 0)

def plot_step_fast(step, sample_cur):
    
    begin = sample_inds[sample_cur]
    end = begin + sample_sizes[sample_cur]
    
    x = poss[step, begin:end, 1]
    y = poss[step, begin:end, 0]
    
    plt.subplot(1, 2, 1)
    plt.axis([-FOV_edge, sample_size_px-FOV_edge, -FOV_edge, sample_size_px-FOV_edge])
    plt.gca().add_patch(Rectangle((0, 0), camera_fov_px, camera_fov_px, edgecolor = 'red', fill=False))
    plt.gca().set_aspect('equal', adjustable='box')
    plt.scatter(x,y)
    
    imgs = sampless[1][sample_cur]
    plt.subplot(1, 2, 2)
    plt.imshow(imgs[step, :, :])
    plt.axis([-0.5, camera_fov_px-0.5, -0.5, camera_fov_px-0.5])
    plt.scatter(x,y, c="red")
    plt.title(str_types[1])
    plt.show()
    


    
interact(plot_step_fast, step=IntSlider(min=0, max=steps - 1, layout=Layout(width='100%')), sample_cur=IntSlider(min=0, max=sample_count - 1, layout=Layout(width='100%')));
# Out:
# interactive(children=(IntSlider(value=0, description='step', layout=Layout(width='100%'), max=63), IntSlider(v…

# %%
#Draw Fast & Generate targets
sample_inds = np.insert(np.cumsum(sample_sizes), 0, 0)

xc_in_sight = (poss[:, :, 0] > 0) & (poss[:, :, 0] < camera_fov_px)
yc_in_sight = (poss[:, :, 1] > 0) & (poss[:, :, 1] < camera_fov_px)
pt_in_sight = xc_in_sight & yc_in_sight

particles_in_sight_cnt = list()
for i in range(sample_count):
    particles_in_sight_cnt.append(np.sum(pt_in_sight[:, sample_inds[i]:sample_inds[i+1]], axis = 1))

precision_multiplier = 4
targets = np.zeros((steps, sample_count, camera_fov_px * precision_multiplier, camera_fov_px * precision_multiplier), dtype=np.uint8)

for i in range(sample_count):
    for step in range(steps):
        sample_pt = np.nonzero(pt_in_sight[step, sample_inds[i]:sample_inds[i+1]])
        sample_ps = poss[step, sample_inds[i]:sample_inds[i+1], :]
        positions_in_sight = (sample_ps[sample_pt, :] * precision_multiplier).astype(int)[0]
        targets[step, i, positions_in_sight[:, 0], positions_in_sight[:, 1]] = 1
    
    


def plot_step_fast_wTargets(step, sample_cur):
    
    begin = sample_inds[sample_cur]
    end = begin + sample_sizes[sample_cur]
    
    x = poss[step, begin:end, 1]
    y = poss[step, begin:end, 0]
    
    plt.subplot(1, 2, 1)
    plt.axis([-FOV_edge, sample_size_px-FOV_edge, -FOV_edge, sample_size_px-FOV_edge])
    plt.gca().add_patch(Rectangle((0, 0), camera_fov_px, camera_fov_px, edgecolor = 'red', fill=False))
    plt.gca().set_aspect('equal', adjustable='box')
    plt.scatter(x,y)
    
    imgs = sampless[1][sample_cur]
    plt.subplot(1, 2, 2)
    plt.imshow(imgs[step, :, :])
    plt.axis([-0.5, camera_fov_px-0.5, -0.5, camera_fov_px-0.5])
    plt.scatter(x,y, c="red")
    plt.title(str_types[1])
    plt.show()
    
    plt.imshow(targets[step, sample_cur, :, :])
    plt.axis([-0.5, camera_fov_px * precision_multiplier-0.5, -0.5, camera_fov_px * precision_multiplier-0.5])
    plt.show()
    print(particles_in_sight_cnt[sample_cur][step])
    


    
interact(plot_step_fast_wTargets, step=IntSlider(min=0, max=steps - 1, layout=Layout(width='100%')), sample_cur=IntSlider(min=0, max=sample_count - 1, layout=Layout(width='100%')));
# Out:
# interactive(children=(IntSlider(value=0, description='step', layout=Layout(width='100%'), max=63), IntSlider(v…

# %%
#Draw All
sample_inds = np.insert(np.cumsum(sample_sizes), 0, 0)

def plot_step(step, sample_cur):
    
    begin = sample_inds[sample_cur]
    end = begin + sample_sizes[sample_cur]
    
    x = poss[step, begin:end, 1]
    y = poss[step, begin:end, 0]
    
    plt.figure()
    plt.axis([-FOV_edge, sample_size_px-FOV_edge, -FOV_edge, sample_size_px-FOV_edge])
    plt.gca().add_patch(Rectangle((0, 0), camera_fov_px, camera_fov_px, edgecolor = 'red', fill=False))
    plt.scatter(x,y)
    plt.show()
    
    for d in range(len(str_types)):
        imgs = sampless[d][sample_cur]
        plt.subplot(1, 2, d%2 + 1)
        plt.imshow(imgs[step, :, :])
        plt.axis([-0.5, camera_fov_px-0.5, -0.5, camera_fov_px-0.5])
        plt.scatter(x,y, c="red")
        plt.title(str_types[d])
        
        if (d + 1) % 2 == 0:
            plt.show()
    


    
interact(plot_step, step=IntSlider(min=0, max=steps - 1, layout=Layout(width='100%')), sample_cur=IntSlider(min=0, max=sample_count - 1, layout=Layout(width='100%')));
# Out:
# interactive(children=(IntSlider(value=0, description='step', layout=Layout(width='100%'), max=63), IntSlider(v…
